# %% [markdown]
# <a href="https://colab.research.google.com/github/NikhithaN-lab/blank-app/blob/main/text_to_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y tensorflow keras tensorflow-addons onnx-tf onnx torch torchvision torchaudio diffusers transformers accelerate
# Out:
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0
# Found existing installation: keras 3.8.0
# Uninstalling keras-3.8.0:
#   Successfully uninstalled keras-3.8.0
# Found existing installation: tensorflow-addons 0.23.0
# Uninstalling tensorflow-addons-0.23.0:
#   Successfully uninstalled tensorflow-addons-0.23.0
# Found existing installation: onnx-tf 1.10.0
# Uninstalling onnx-tf-1.10.0:
#   Successfully uninstalled onnx-tf-1.10.0
# Found existing installation: onnx 1.17.0
# Uninstalling onnx-1.17.0:
#   Successfully uninstalled onnx-1.17.0
# Found existing installation: torch 2.0.1+cu118
# Uninstalling torch-2.0.1+cu118:
#   Successfully uninstalled torch-2.0.1+cu118
# Found existing installation: torchvision 0.15.2+cu118
# Uninstalling torchvision-0.15.2+cu118:
#   Successfully uninstalled torchvision-0.15.2+cu118
# Found existing installation: torchaudio 2.0.2+cu118
# Uninstalling torchaudio-2.0.2+cu118:
# ...

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            1.4.0
# aiohappyeyeballs                   2.4.4
# aiohttp                            3.11.11
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.19
# albumentations                     1.4.20
# ale-py                             0.10.1
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.6.0
# arviz                              0.20.0
# astropy                            6.1.7
# astropy-iers-data                  0.2025.1.27.0.32.44
# astunparse                         1.6.3
# atpublic                           4.1.0
# attrs                              25.1.0
# ...

# %%
# Step 1: Uninstall all conflicting packages
# !pip uninstall -y torch torchvision torchaudio tensorflow tensorflow-addons typeguard inflect diffusers transformers

# Step 2: Install PyTorch and torchvision with compatible CUDA versions
# !pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 --index-url https://download.pytorch.org/whl/cu118

# Step 3: Install TensorFlow and related packages
# !pip install tensorflow==2.18.0

# Step 4: Install compatible versions of typeguard and tensorflow-addons
# !pip install typeguard==2.13.3 tensorflow-addons==0.23.0

# Step 5: Install Diffusers, Transformers, and other required libraries
# !pip install diffusers transformers accelerate onnx onnx-tf

# Step 6: Verify the installation
import torch
import torchvision
import tensorflow as tf

print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("TensorFlow version:", tf.__version__)
# Out:
# WARNING: Skipping torch as it is not installed.
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# WARNING: Skipping tensorflow as it is not installed.
# WARNING: Skipping tensorflow-addons as it is not installed.
# Found existing installation: typeguard 4.0.1
# Uninstalling typeguard-4.0.1:
#   Successfully uninstalled typeguard-4.0.1
# WARNING: Skipping inflect as it is not installed.
# WARNING: Skipping diffusers as it is not installed.
# WARNING: Skipping transformers as it is not installed.
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#   Using cached https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp311-cp311-linux_x86_64.whl (2267.3 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu118/torchvision-0.15.2%2Bcu118-cp311-cp311-linux_x86_64.whl (6.1 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu118/torchaudio-2.0.2%2Bcu118-cp311-cp311-linux_x86_64.whl (4.4 MB)
# ...

# %%
# Step 1: Upgrade PyTorch and torchvision
# !pip install torch==2.1.0 torchvision==0.16.0 torchaudio==2.1.0 --index-url https://download.pytorch.org/whl/cu118

# Step 2: Upgrade the diffusers library
# !pip install --upgrade diffusers

# Step 3: Verify the installation
import torch
import diffusers

print("PyTorch version:", torch.__version__)
print("Diffusers version:", diffusers.__version__)

# Step 4: Run the Stable Diffusion pipeline
from diffusers import StableDiffusionPipeline
from IPython.display import Image, display

# Load the Stable Diffusion model
model_id = "stabilityai/sd-turbo"  # Use a lightweight model
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32)
pipe = pipe.to(device)

# Generate the image
prompt = "A futuristic city at sunset"
image = pipe(prompt).images[0]

# Save and display the image
image_path = "generated_image.png"
image.save(image_path)
display(Image(filename=image_path))
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
# PyTorch version: 2.0.1+cu118
# Diffusers version: 0.32.2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/diffusers/utils/import_utils.py in _get_module(self, module_name)
#     919         try:
# --> 920             return importlib.import_module("." + module_name, self.__name__)
#     921         except Exception as e:
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ...

# %%
# !pip uninstall -y torch torchvision torchaudio diffusers
# Out:
# Found existing installation: torch 2.1.0+cu118
# Uninstalling torch-2.1.0+cu118:
#   Successfully uninstalled torch-2.1.0+cu118
# Found existing installation: torchvision 0.16.0+cu118
# Uninstalling torchvision-0.16.0+cu118:
#   Successfully uninstalled torchvision-0.16.0+cu118
# Found existing installation: torchaudio 2.1.0+cu118
# Uninstalling torchaudio-2.1.0+cu118:
#   Successfully uninstalled torchaudio-2.1.0+cu118
# Found existing installation: diffusers 0.32.2
# Uninstalling diffusers-0.32.2:
#   Successfully uninstalled diffusers-0.32.2

# %%
# Install PyTorch 2.1.0 with CUDA 11.8 support
# !pip install torch==2.1.0 torchvision==0.16.0 torchaudio==2.1.0 --index-url https://download.pytorch.org/whl/cu118

# Install the latest version of diffusers
# !pip install --upgrade diffusers
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
import torch
import diffusers

print("PyTorch version:", torch.__version__)
print("Diffusers version:", diffusers.__version__)
# Out:
# PyTorch version: 2.1.0+cu118
# Diffusers version: 0.32.2

# %%
from diffusers import StableDiffusionPipeline
from IPython.display import Image, display

# Load the Stable Diffusion model
model_id = "stabilityai/sd-turbo"  # Use a lightweight model
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32)
pipe = pipe.to(device)

# Generate the image
prompt = "A futuristic city at sunset"
image = pipe(prompt).images[0]

# Save and display the image
image_path = "generated_image.png"
image.save(image_path)
display(Image(filename=image_path))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# text_encoder/config.json:   0%|          | 0.00/618 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/1.87k [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/574 [00:00<?, ?B/s]
# ...

# %%
import torch
from diffusers import StableDiffusionPipeline

# Load the Stable Diffusion model
model_id = "stabilityai/sd-turbo"  # Use a lightweight model
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32)
pipe = pipe.to(device)

# Export the UNet model to ONNX
unet = pipe.unet
dummy_input = torch.randn(1, 4, 64, 64).to(device)  # Example input shape for UNet
onnx_model_path = "unet_model.onnx"

# Export to ONNX
torch.onnx.export(
    unet,
    dummy_input,
    onnx_model_path,
    export_params=True,
    opset_version=14,  # Use ONNX opset 14 for compatibility
    do_constant_folding=True,
    input_names=["input"],
    output_names=["output"],
    dynamic_axes={"input": {0: "batch_size"}, "output": {0: "batch_size"}},
)

print(f"✅ UNet model exported to ONNX at {onnx_model_path}")
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# ...

# %%
import torch
from diffusers import StableDiffusionPipeline

# Load the Stable Diffusion model
model_id = "stabilityai/sd-turbo"  # Use a lightweight model
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32)
pipe = pipe.to(device)

# Export the UNet model to ONNX
unet = pipe.unet

# Example inputs for UNet
latent_input = torch.randn(1, 4, 64, 64).to(device)  # Latent image representation
timestep = torch.tensor([0], dtype=torch.int64).to(device)  # Timestep input
encoder_hidden_states = torch.randn(1, 77, 768).to(device)  # Text embeddings

# Export to ONNX
onnx_model_path = "unet_model.onnx"
torch.onnx.export(
    unet,
    (latent_input, timestep, encoder_hidden_states),  # Provide all required inputs
    onnx_model_path,
    export_params=True,
    opset_version=14,  # Use ONNX opset 14 for compatibility
    do_constant_folding=True,
    input_names=["latent_input", "timestep", "encoder_hidden_states"],
    output_names=["output"],
    dynamic_axes={
        "latent_input": {0: "batch_size"},
        "timestep": {0: "batch_size"},
        "encoder_hidden_states": {0: "batch_size"},
        "output": {0: "batch_size"},
    },
)

print(f"✅ UNet model exported to ONNX at {onnx_model_path}")
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-b4ebffec1ee3> in <cell line: 0>()
#      18 # Export to ONNX
# ...

# %%
import torch
from diffusers import StableDiffusionPipeline

# Load the Stable Diffusion model
model_id = "stabilityai/sd-turbo"  # Use a lightweight model
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32)
pipe = pipe.to(device)

# Export the UNet model to ONNX
unet = pipe.unet

# Example inputs for UNet
latent_input = torch.randn(1, 4, 64, 64).to(device, dtype=torch.float16)  # Latent image representation (match model dtype)
timestep = torch.tensor([0], dtype=torch.int64).to(device)  # Timestep input
encoder_hidden_states = torch.randn(1, 77, 768).to(device, dtype=torch.float16)  # Text embeddings (match model dtype)

# Export to ONNX
onnx_model_path = "unet_model.onnx"
torch.onnx.export(
    unet,
    (latent_input, timestep, encoder_hidden_states),  # Provide all required inputs
    onnx_model_path,
    export_params=True,
    opset_version=14,  # Use ONNX opset 14 for compatibility
    do_constant_folding=True,
    input_names=["latent_input", "timestep", "encoder_hidden_states"],
    output_names=["output"],
    dynamic_axes={
        "latent_input": {0: "batch_size"},
        "timestep": {0: "batch_size"},
        "encoder_hidden_states": {0: "batch_size"},
        "output": {0: "batch_size"},
    },
)

print(f"✅ UNet model exported to ONNX at {onnx_model_path}")
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-6e97adcc4dc9> in <cell line: 0>()
#      18 # Export to ONNX
# ...

# %%
import torch
from diffusers import StableDiffusionPipeline

# Load the Stable Diffusion model
model_id = "stabilityai/sd-turbo"  # Use a lightweight model
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32)
pipe = pipe.to(device)

# Export the UNet model to ONNX
unet = pipe.unet

# Convert UNet to float32 for ONNX export
unet = unet.to(torch.float32)

# Example inputs for UNet
latent_input = torch.randn(1, 4, 64, 64).to(device, dtype=torch.float32)  # Latent image representation (float32)
timestep = torch.tensor([0], dtype=torch.int64).to(device)  # Timestep input
encoder_hidden_states = torch.randn(1, 77, 768).to(device, dtype=torch.float32)  # Text embeddings (float32)

# Export to ONNX
onnx_model_path = "unet_model.onnx"
torch.onnx.export(
    unet,
    (latent_input, timestep, encoder_hidden_states),  # Provide all required inputs
    onnx_model_path,
    export_params=True,
    opset_version=14,  # Use ONNX opset 14 for compatibility
    do_constant_folding=True,
    input_names=["latent_input", "timestep", "encoder_hidden_states"],
    output_names=["output"],
    dynamic_axes={
        "latent_input": {0: "batch_size"},
        "timestep": {0: "batch_size"},
        "encoder_hidden_states": {0: "batch_size"},
        "output": {0: "batch_size"},
    },
)

print(f"✅ UNet model exported to ONNX at {onnx_model_path}")
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# ...

# %%
print("latent_input shape:", latent_input.shape)
print("timestep shape:", timestep.shape)
print("encoder_hidden_states shape:", encoder_hidden_states.shape)
# Out:
# latent_input shape: torch.Size([1, 4, 64, 64])
# timestep shape: torch.Size([1])
# encoder_hidden_states shape: torch.Size([1, 77, 768])

# %%
import torch
from diffusers import StableDiffusionPipeline

# Load the Stable Diffusion model
model_id = "stabilityai/sd-turbo"  # Use a lightweight model
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32)
pipe = pipe.to(device)

# Export the UNet model to ONNX
unet = pipe.unet

# Convert UNet to float32 for ONNX export
unet = unet.to(torch.float32)

# Example inputs for UNet
latent_input = torch.randn(1, 4, 64, 64).to(device, dtype=torch.float32)  # Latent image representation (float32)
timestep = torch.tensor([0], dtype=torch.int64).to(device)  # Timestep input

# Generate encoder_hidden_states using the text encoder
prompt = "A futuristic city at sunset"
text_inputs = pipe.tokenizer(
    prompt,
    padding="max_length",
    max_length=pipe.tokenizer.model_max_length,
    truncation=True,
    return_tensors="pt",
)
text_input_ids = text_inputs.input_ids.to(device)
encoder_hidden_states = pipe.text_encoder(text_input_ids)[0].to(torch.float32)  # Text embeddings (float32)

# Export to ONNX
onnx_model_path = "unet_model.onnx"
torch.onnx.export(
    unet,
    (latent_input, timestep, encoder_hidden_states),  # Provide all required inputs
    onnx_model_path,
    export_params=True,
    opset_version=14,  # Use ONNX opset 14 for compatibility
    do_constant_folding=True,
    input_names=["latent_input", "timestep", "encoder_hidden_states"],
    output_names=["output"],
    dynamic_axes={
        "latent_input": {0: "batch_size"},
        "timestep": {0: "batch_size"},
        "encoder_hidden_states": {0: "batch_size"},
        "output": {0: "batch_size"},
    },
)

print(f"✅ UNet model exported to ONNX at {onnx_model_path}")
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-b6c7b2e65aa3> in <cell line: 0>()
#       5 model_id = "stabilityai/sd-turbo"  # Use a lightweight model
#       6 device = "cuda" if torch.cuda.is_available() else "cpu"
# ----> 7 pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32)
#       8 pipe = pipe.to(device)
#       9
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# ...

# %%
import torch
from diffusers import StableDiffusionPipeline

print("Loading model...")
model_id = "stabilityai/sd-turbo"  # Use a lightweight model
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32)
pipe = pipe.to(device)
print("Model loaded successfully.")

# Export the UNet model to ONNX
unet = pipe.unet

# Convert UNet to float32 for ONNX export
unet = unet.to(torch.float32)

# Example inputs for UNet
latent_input = torch.randn(1, 4, 64, 64).to(device, dtype=torch.float32)  # Latent image representation (float32)
timestep = torch.tensor([0], dtype=torch.int64).to(device)  # Timestep input

# Generate encoder_hidden_states using the text encoder
prompt = "A futuristic city at sunset"
text_inputs = pipe.tokenizer(
    prompt,
    padding="max_length",
    max_length=pipe.tokenizer.model_max_length,
    truncation=True,
    return_tensors="pt",
)
text_input_ids = text_inputs.input_ids.to(device)
encoder_hidden_states = pipe.text_encoder(text_input_ids)[0].to(torch.float32)  # Text embeddings (float32)

# Export to ONNX
onnx_model_path = "unet_model.onnx"
print("Exporting UNet model to ONNX...")
torch.onnx.export(
    unet,
    (latent_input, timestep, encoder_hidden_states),  # Provide all required inputs
    onnx_model_path,
    export_params=True,
    opset_version=14,  # Use ONNX opset 14 for compatibility
    do_constant_folding=True,
    input_names=["latent_input", "timestep", "encoder_hidden_states"],
    output_names=["output"],
    dynamic_axes={
        "latent_input": {0: "batch_size"},
        "timestep": {0: "batch_size"},
        "encoder_hidden_states": {0: "batch_size"},
        "output": {0: "batch_size"},
    },
)

print(f"✅ UNet model exported to ONNX at {onnx_model_path}")
# Out:
# Loading model...
# Using device: cuda
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# Model loaded successfully.
# Exporting UNet model to ONNX...
# ...

# %%
pip install onnx tf2onnx tensorflow

# %%
import onnx
import tensorflow as tf
from onnx_tf.backend import prepare

# Load the ONNX model
onnx_model_path = "unet_model.onnx"
onnx_model = onnx.load(onnx_model_path)

# Convert ONNX to TensorFlow SavedModel
tf_rep = prepare(onnx_model)
tf_rep.export_graph("saved_model")
# Out:
# /usr/local/lib/python3.11/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.18.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# ...

# %%
import onnxruntime as ort
import numpy as np

# Load the ONNX model
onnx_model_path = "unet_model.onnx"
session = ort.InferenceSession(onnx_model_path)

# Prepare inputs (example values)
latent_input = np.random.randn(1, 4, 64, 64).astype(np.float32)  # Latent input
timestep = np.array([0], dtype=np.int64)  # Timestep
encoder_hidden_states = np.random.randn(1, 77, 768).astype(np.float32)  # Text embeddings

# Run inference
outputs = session.run(None, {
    "latent_input": latent_input,
    "timestep": timestep,
    "encoder_hidden_states": encoder_hidden_states,
})

print("Inference output shape:", outputs[0].shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-236cab266e98> in <cell line: 0>()
# ----> 1 import onnxruntime as ort
#       2 import numpy as np
#       3
#       4 # Load the ONNX model
#       5 onnx_model_path = "unet_model.onnx"
#
# ModuleNotFoundError: No module named 'onnxruntime'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install onnxruntime-gpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.5/291.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.6 MB/s eta 0:00:00
# ...

# %%
import onnxruntime as ort
print(ort.__version__)
# Out:
# 1.20.1

# %%
import onnxruntime as ort
import numpy as np

# Load the ONNX model
onnx_model_path = "unet_model.onnx"
session = ort.InferenceSession(onnx_model_path)

# Prepare inputs (example values)
latent_input = np.random.randn(1, 4, 64, 64).astype(np.float32)  # Latent input
timestep = np.array([0], dtype=np.int64)  # Timestep
encoder_hidden_states = np.random.randn(1, 77, 768).astype(np.float32)  # Text embeddings

# Run inference
outputs = session.run(None, {
    "latent_input": latent_input,
    "timestep": timestep,
    "encoder_hidden_states": encoder_hidden_states,
})

print("Inference output shape:", outputs[0].shape)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# <ipython-input-36-236cab266e98> in <cell line: 0>()
#      12
#      13 # Run inference
# ---> 14 outputs = session.run(None, {
#      15     "latent_input": latent_input,
#      16     "timestep": timestep,
#
# /usr/local/lib/python3.11/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py in run(self, output_names, input_feed, run_options)
#     264             output_names = [output.name for output in self._outputs_meta]
#     265         try:
# --> 266             return self._sess.run(output_names, input_feed, run_options)
#     267         except C.EPFail as err:
#     268             if self._enable_fallback:
#
# InvalidArgument: [ONNXRuntimeError] : 2 : INVALID_ARGUMENT : Got invalid dimensions for input: encoder_hidden_states for the following indices
#  index: 2 Got: 768 Expected: 1024
# ...

# %%
encoder_hidden_states = pipe.text_encoder(text_input_ids)[0]
print("Encoder hidden states shape:", encoder_hidden_states.shape)
# Out:
# Encoder hidden states shape: torch.Size([1, 77, 1024])

# %%
import torch
from diffusers import StableDiffusionPipeline

# Load the Stable Diffusion model
model_id = "stabilityai/sd-turbo"  # Use a lightweight model
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32)
pipe = pipe.to(device)

# Export the UNet model to ONNX
unet = pipe.unet
unet = unet.to(torch.float32)  # Convert to float32 for ONNX export

# Example inputs for UNet
latent_input = torch.randn(1, 4, 64, 64).to(device, dtype=torch.float32)  # Latent input
timestep = torch.tensor([0], dtype=torch.int64).to(device)  # Timestep
encoder_hidden_states = torch.randn(1, 77, 1024).to(device, dtype=torch.float32)  # Text embeddings

# Export to ONNX
onnx_model_path = "unet_model.onnx"
torch.onnx.export(
    unet,
    (latent_input, timestep, encoder_hidden_states),  # Provide all required inputs
    onnx_model_path,
    export_params=True,
    opset_version=14,  # Use ONNX opset 14 for compatibility
    do_constant_folding=True,
    input_names=["latent_input", "timestep", "encoder_hidden_states"],
    output_names=["output"],
    dynamic_axes={
        "latent_input": {0: "batch_size"},
        "timestep": {0: "batch_size"},
        "encoder_hidden_states": {0: "batch_size"},
        "output": {0: "batch_size"},
    },
)

print(f"✅ UNet model exported to ONNX at {onnx_model_path}")
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# ...

# %%
import onnxruntime as ort
import numpy as np

# Load the ONNX model
onnx_model_path = "unet_model.onnx"
session = ort.InferenceSession(onnx_model_path)

# Check input names
input_names = [input.name for input in session.get_inputs()]
print("Input names:", input_names)

# Prepare inputs (example values)
latent_input = np.random.randn(1, 4, 64, 64).astype(np.float32)  # Latent input
timestep = np.array([0], dtype=np.int64)  # Timestep
encoder_hidden_states = np.random.randn(1, 77, 1024).astype(np.float32)  # Text embeddings

# Run inference
outputs = session.run(None, {
    input_names[0]: latent_input,  # latent_input
    input_names[1]: timestep,      # timestep
    input_names[2]: encoder_hidden_states,  # encoder_hidden_states
})

print("Inference output shape:", outputs[0].shape)
# Out:
# Input names: ['latent_input', 'timestep', 'encoder_hidden_states']
# Inference output shape: (1, 4, 64, 64)

# %%
import 'package:flutter/material.dart';
import 'package:onnxruntime_flutter/onnxruntime_flutter.dart';

void main() {
  runApp(TextToImageApp());
}

class TextToImageApp extends StatelessWidget {
  @override
  Widget build(BuildContext context) {
    return MaterialApp(
      title: 'Text-to-Image Generator',
      theme: ThemeData(primarySwatch: Colors.blue),
      home: TextToImageScreen(),
    );
  }
}

class TextToImageScreen extends StatefulWidget {
  @override
  _TextToImageScreenState createState() => _TextToImageScreenState();
}

class _TextToImageScreenState extends State<TextToImageScreen> {
  final _textController = TextEditingController();
  String _imagePath = "";

  Future<void> _generateImage(String prompt) async {
    try {
      // Load the ONNX model
      final session = await InferenceSession.create("assets/unet_model.onnx");

      // Prepare inputs (example values)
      final latentInput = List.filled(1 * 4 * 64 * 64, 0.0).reshape([1, 4, 64, 64]);
      final timestep = List.filled(1, 0).reshape([1]);
      final encoderHiddenStates = List.filled(1 * 77 * 1024, 0.0).reshape([1, 77, 1024]);

      // Run inference
      final outputs = await session.run({
        "latent_input": latentInput,
        "timestep": timestep,
        "encoder_hidden_states": encoderHiddenStates,
      });


      setState(() {
        _imagePath = "assets/placeholder.png";  // Replace with actual image processing logic
      });
    } catch (e) {
      print("Error generating image: $e");
    }
  }

  @override
  Widget build(BuildContext context) {
    return Scaffold(
      appBar: AppBar(title: Text("Text-to-Image Generator")),
      body: Column(
        children: [
          TextField(
            controller: _textController,
            decoration: InputDecoration(labelText: "Enter a prompt"),
          ),
          ElevatedButton(
            onPressed: () => _generateImage(_textController.text),
            child: Text("Generate Image"),
          ),
          if (_imagePath.isNotEmpty) Image.asset(_imagePath),
        ],
      ),
    );
  }
}
# Out:
#   File "<ipython-input-42-9bb9deb31579>", line 1
#     import 'package:flutter/material.dart';
#            ^
# SyntaxError: invalid syntax
